# %%
# Install gdown
# !pip install gdown > /dev/null
import gdown
url = ['135mDCHD3XXfMHi27Ut_6kTa5oEIWwh3a', '1XsOQtieYRgNWmjN_jV-9-i7oarRAB5M4']

for i in range(len(url)):
    gdown.download('https://drive.google.com/uc?export=download&id='+url[i], quiet=False)
# !unzip /kaggle/working/data.zip
# Out:
# Downloading...
# From (uriginal): https://drive.google.com/uc?export=download&id=135mDCHD3XXfMHi27Ut_6kTa5oEIWwh3a
# From (redirected): https://drive.google.com/uc?export=download&id=135mDCHD3XXfMHi27Ut_6kTa5oEIWwh3a&confirm=t&uuid=d949bbc5-bb72-4d33-9bba-6d0e9f7c70f1
# To: /kaggle/working/data.zip
# 100%|██████████| 225M/225M [00:02<00:00, 79.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1XsOQtieYRgNWmjN_jV-9-i7oarRAB5M4
# To: /kaggle/working/config.yaml
# 100%|██████████| 604/604 [00:00<00:00, 1.70MB/s]
# Archive:  /kaggle/working/data.zip
#    creating: data/images/
#    creating: data/images/train/
#   inflating: data/images/train/IMG_20200123_203339.jpg
#   inflating: data/images/train/IMG_20230710_154038.jpg
#   inflating: data/images/train/IMG_20230710_154049.jpg
#   inflating: data/images/train/IMG_20230710_154059.jpg
#   inflating: data/images/train/IMG_20230710_154126.jpg
#   inflating: data/images/train/IMG_20230710_154136.jpg
# ...

# %%
# !pip install albumentations
# !pip install ultralytics
from ultralytics import YOLO
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 605.4/605.4 kB 10.9 MB/s eta 0:00:00
# ...
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
model = YOLO('yolov8x.pt')  # load a pretrained model (recommended for training)
# Out:
# ...
# 100%|██████████| 131M/131M [00:00<00:00, 231MB/s]

# %%
model.train(data='/kaggle/working/config.yaml', epochs=300, batch=16, imgsz=640)
# Out:
# Ultralytics YOLOv8.0.136 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
# ...

# %%
# !zip  /kaggle/working/model.rar

# %%
import shutil

shutil.make_archive('/kaggle/working/model', 'zip', '/kaggle/working/runs/detect/train')
